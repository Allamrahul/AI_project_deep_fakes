# %%
from google.colab import drive
drive.mount('/content/gdrive')

masked_raw = '/content/gdrive/MyDrive/Dataset/Masked'
unmasked_raw = '/content/gdrive/MyDrive/Dataset/Unmasked'
# Out:
# Mounted at /content/gdrive

# %%
# ! git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix.git
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2428, done.
# remote: Total 2428 (delta 0), reused 0 (delta 0), pack-reused 2428
# Receiving objects: 100% (2428/2428), 8.13 MiB | 10.80 MiB/s, done.
# Resolving deltas: 100% (1561/1561), done.

# %%
# %cd /content/gdrive/MyDrive/Workspace/pytorch-CycleGAN-and-pix2pix/
# Out:
# /content/gdrive/MyDrive/Workspace/pytorch-CycleGAN-and-pix2pix

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 35.0 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 180 kB 47.0 MB/s
# ...
#      |████████████████████████████████| 139 kB 48.5 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=2d7e6d58d911e108892cc0c1ee6fa1fe673247c37023ca8b2ec0727460b9a8cc
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=8ffaa156a6dcf003e707ae75246588437875d1e9272f7fa034665e2ff615cffb
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread(masked_raw + '/T1' + '/00007_Mask.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
# !python train.py --dataroot ./datasets/unmasked_2_masked --name unmasked_2_masked --model cycle_gan --use_wandb
# Out:
# ----------------- Options ---------------
#                batch_size: 14
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 128
#                  dataroot: ./datasets/unmasked_2_masked  	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
# ...

# %%
dddddddddfffggghjkjkjkllksdkkggjklkljhgfdkkkkkkkkkkkkkkhjjhjklkghjkl

# %%
# !python test.py --dataroot ./datasets/unmasked_2_masked --name unmasked_2_masked --model test --no_dropout --use_wandb
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/unmasked_2_masked  	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: unmasked_2_masked             	[default: experiment_name]
#                       ndf: 64
# ...
